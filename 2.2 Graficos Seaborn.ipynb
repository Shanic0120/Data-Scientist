# %% [markdown]
# # [Seaborn](https://seaborn.pydata.org)
#
# [Cheat Sheet](https://deeplearning.fr/seaborn-cheats/)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Displot
#
# Para distribuciones

# %%
sns.displot(data=tips,
            x="total_bill",
            hue="sex",
            kind="kde",
            legend=True,
            palette="dark")
plt.show()

# %%
sns.displot(data=tips,
            x="total_bill",
            y="tip",
            hue="sex" # Agrupamiento
            )
plt.show()

# %% [markdown]
# ## Histplot

# %%
sns.histplot(tips, x="tip", bins=15,
             cumulative=False, # Ir sumando los valores
             hue="sex", # Agrupamiento
             stat="count", # En vez del conteo muestra la estadistica (count, frequency, probability, percent, dencity)
             multiple="dodge", # Como se comparan los histogramas(layer, stack, dodge, fill)
             )
plt.show()

# %% [markdown]
# ## Kdeplot (Densidad)

# %%
# sns.kdeplot(tips, x="tip", hue="sex",
#             cumulative=False,
#             fill=True, # Relleno
#             bw_adjust=1, # Ajustar la grafica a los parametros de los ejes
#             )

# %% [markdown]
# ## Ecdfplot

# %%
sns.ecdfplot(tips, x="tip", hue="sex")
plt.show()

# %% [markdown]
# ## Countplot

# %%
sns.countplot(tips, x="day", hue="sex")
plt.show()

# %% [markdown]
# ## Stripplot

# %%
sns.stripplot(tips, x="day", y="total_bill", hue="sex", dodge=True)
plt.show()

# %% [markdown]
# ## Swarmplot

# %%
sns.swarmplot(tips, x="day", y="total_bill", hue="sex", dodge=True)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(tips, x="day", y="total_bill", hue="sex", dodge=True)
sns.swarmplot(tips, x="day", y="total_bill", hue="sex", dodge=True, palette="dark")
plt.show()

# %% [markdown]
# ## Violinplot

# %%
sns.violinplot(tips, x="day", y="total_bill", hue="sex", dodge=True)
sns.swarmplot(tips, x="day", y="total_bill", hue="sex", dodge=True, palette="pastel")
plt.show()

# %% [markdown]
# ## Catplot

# %%
sns.catplot(tips, x="day", y="total_bill", hue="sex", dodge=True)
plt.show()

# %%
sns.catplot(tips, x="day", y="total_bill", hue="sex", dodge=True, col="time")
plt.show()

# %% [markdown]
# ## ScatterPlot

# %%
markers = {"Male":"D", "Female":"s"}
sns.scatterplot(tips, x="total_bill", y="tip", hue="day", style="sex",
                size="size",
                markers=markers)
plt.legend(loc="center", bbox_to_anchor=(1.12, 0.5))
plt.show()

# %% [markdown]
# ## Lineplot

# %%
sns.lineplot(tips, x="total_bill", y="tip", hue="day", style="sex")
plt.legend(loc="center", bbox_to_anchor=(1.12, 0.5))
plt.show()

# %% [markdown]
# ## Relplot

# %%
sns.relplot(tips, x="total_bill", y="tip", hue="day", style="sex", kind="scatter",
            col="time")
# plt.legend(loc="center", bbox_to_anchor=(1.12, 0.5))
plt.show()

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(tips, x="total_bill", y="tip", hue="sex", kind="scatter")
plt.show()

# %%
sns.jointplot(tips, x="total_bill", y="tip", hue="sex", kind="hist")
plt.show()

# %%
sns.jointplot(tips, x="total_bill", y="tip", hue="sex", kind="hist", 
              marginal_ticks=True, marginal_kws=dict(bins=25, multiple="dodge"))
plt.show()

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips, hue="sex", palette="coolwarm", corner=True, kind="reg")
plt.show()

# %% [markdown]
# ## Regplot

# %%
sns.regplot(tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Heatmap

# %%
tips.corr()
# Out:
# C:\Users\shani\AppData\Local\Temp\ipykernel_6580\3825555837.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cbar=False)
plt.show()
# Out:
# C:\Users\shani\AppData\Local\Temp\ipykernel_6580\1089559808.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(), cbar=False)

# %%
sns.heatmap(tips.corr(), annot=True, cmap="coolwarm", linewidths=5,
            vmin=-1, vmax=1)
plt.show()
# Out:
# C:\Users\shani\AppData\Local\Temp\ipykernel_6580\2100021090.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(), annot=True, cmap="coolwarm", linewidths=5,
