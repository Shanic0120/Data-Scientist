# %% [markdown]
# # Funciones Metemáticos para Data Science

# %% [markdown]
# ## ¿Qué es una función?
#
# Es una regla en donde se obtiene un valor $y$ dado $x$, una función solo es función si para un $x$ solo hay una $y$ posible.
#
# En otras palabras, la variable dependiente depende, valga la redundancia, de una o más variables independientes
#
# $y=f(x)$
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Por ejemplo se puede obtener el tiempo que demora de un lugar a otro dada la distancia y la velocidad.

# %% [markdown]
# ## Tipos de variables
#
# ![image-2.png](attachment:image-2.png)
#
# - Cualitativas
#
#     - Nominales: Son las que se les asigna una cualidad. Por ejemplo un color.
#
#     - Ordinales: Que tienen un orden. Por ejemplo: alto, medio, bajo.
#
#     - Binarias: Representan estados, que toman dos valores. Por ejemplo: Existe, género.
#
# - Cuantitativas
#
#     - Discretas: Son finitas y toman ciertos valores, pueden verse como variables separadas por un "paso". Por ejemplo, una persona puede tener 1,  2 o 3 amigos, nuna 3.5.
#
#     - Continuas: Pueden verse como infinitos dentro de los reales en un rango establecido. Por ejemplo, la estatura.

# %% [markdown]
# ## Dominio
#
# Los valores que toma $x$ y que están definidos en $f(x)$
#
# ## Rango
#
# Los resultados que puede tomar $y$

# %% [markdown]
# ## Conjuntos
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Funciones algebraicas lineales

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Función lineal
#
# Tiene la forma:$$f(x)=mx+b$$
#
# donde $m$ y $b \in R $
#
# $m$ puede ser calculada por:
#
# $$m=\frac{y_2-y_1}{x_2-x_1}$$
#
# $m = \tan(\theta)$
#
# Y $b$ es el punto de corte con el eje$y$.
#
# $Dom_f=(-\inf,\inf)$
#
# $Ran_f=(-\inf,\inf)$

# %%
N = 100

m = np.random.uniform(-5, 10)
b = np.random.uniform(-10, 10)

def f(x):
    return m*x+b

x = np.linspace(-10, 10, num=N)
y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$y={m}x+({b})$")
ax.grid()
plt.show()

# %% [markdown]
# ### Función polinómica
#
# $$P(x)=a_{n}x^{n}+a_{n-1}x^{n-1}+...+a_{2}x^{2}+a_{1}x^{1}+a_1$$
#
# Son de grado n
#
# Ejemplo:
#
# $$P(x)=2x^7-x^4+3x^2+4$$

# %%
# Ejemplo de polinomio grado 7
def P(x):
    return (2*x**7)-(x**4)+(3*x**2)+4

x = np.linspace(-10, 10, num=100)
y = P(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$P(x)=2x^7-x^4+3x^2+4$")
ax.grid()
plt.show()

# %% [markdown]
# ### Funciones potencia
#
# $$f(x)=x^a,a\in{R}$$
#
# Ejemplo:$$f(x)=x^2$$

# %%
def f(x):
    return x**2

x = np.linspace(-10, 10, num=100)
y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$y=x^2$")
ax.grid()
plt.show()

# %% [markdown]
# ## Funciones trascendentes

# %% [markdown]
# ### Funciones trigonometricas
#
# Ejemplos: $\cos(x)$, $\sin(x)$ y $\tan(x)$

# %%
def f(x):
    return np.sin(x)

x = np.linspace(-10, 10, num=100)
y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$y=\sin(x)$")
ax.grid()
plt.show()

# %% [markdown]
# ### Funciones exponenciales
#
# $$f(x)=a^x$$

# %%
def f(x):
    return np.exp(x)

x = np.linspace(-10, 10, num=100)
y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$y=e^x$")
ax.grid()
plt.show()

# %% [markdown]
# ### Función logaritmica
#
# $$\log_b(x)=n \Leftrightarrow x=b^n$$
#
# Ejemplo: $$\log_2(256)=8 \Leftrightarrow 256=2^8$$

# %%
def f(x):
    return np.log2(x)

x = np.linspace(0.0001, 10, num=100) # Recordemos que los logaritmos no reciben números negativos
y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$y=\log_2(x)$")
ax.grid()
plt.show()

# %% [markdown]
# ### Funciones seccionadas
#
# Son funciones que están dadas por intervalos. Por ejemplo:
#
# $$H(x) =
#      \begin{cases}
#         0, &\quad \text{para } x < 0 \\
#         1,  &\quad\text{para } x \ge 0 \\
#      \end{cases}
# $$

# %%
def H(x):
    Y = np.zeros(len(x))
    for idx, x in enumerate(x):
        if x >= 0:
            Y[idx]=1
    return Y

x = np.linspace(-10, 10, num=100) # Recordemos que los logaritmos no reciben números negativos
y = H(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
plt.show()

# %% [markdown]
# ## Funciones compuestas
#
# Una función compuesta se obtiene cuando se pasa como argumento de la función principal el valor de otra función. En otras palabras:
#
# $$g(f(x))$$

# %%
def f(x):
    return x**2

def g(x):
    return np.sin(x)

x = np.linspace(-10, 10, num=1000)
y = g(f(x))

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"$y=\sin(x^2)$")
ax.grid()
plt.show()

# %% [markdown]
# ## Manipulación de funciones

# %% [markdown]
# ### Desplazamiento
#
# Siendo $c$ una constante mayor que cero, entonces la gráfica:
#
# - $y=f(x)+c$ se desplaza $c$ unidades hacia arriba.
# - $y=f(x)-c$ se desplaza $c$ unidades hacia abajo.
# - $y=f(x-c)$ se desplaza $c$ unidades hacia la derecha.
# - $y=f(x+c)$ se desplaza $c$ unidades hacia la izquierda.

# %%
N = 1000

def f(x):
  return x**2;

c = 4

x = np.linspace(-10,10, num=N)

y = f(x + c)

fig, ax = plt.subplots()
ax.plot(x,y,label="Modificada")
ax.plot(x, f(x),label="Original")
ax.legend()
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ### Alargamientos y compresiones
#
# Siendo $c$ una constante mayor que cero, entonces la gráfica:
#
# - $y=c \cdot f(x)$ alarga la gráfica verticalmente en un factor de $c$.
# - $y= \frac{1}{c} \cdot f(x)$ comprime la gráfica verticalmente en un factor de $c$.
# - $y=f(c \cdot x)$ comprime la gráfica horizontelmente en un factor de $c$.
# - $y= f(\frac{1}{c} \cdot x )$ alarga la gráfica horizontelmente en un factor de $c$.

# %%
N = 1000

def f(x):
  return np.sin(x);

c = 2

x = np.linspace(-15,15, num=N)

y = f((1/c)*x)


fig, ax = plt.subplots()
ax.plot(x,y,label="Modificada")
ax.plot(x, f(x),label="Original")
ax.legend()
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ### Reflexiones
#
# - $y=-f(x)$ refleja la gráfica respecto al eje x.
# - $y=f(-x)$ refleja la gráfica respecto al eje y.

# %%
N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)

y = f(-x)

fig, ax = plt.subplots()
ax.plot(x,y,label="Modificada")
ax.plot(x, f(x),label="Original")
ax.legend()
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='r')

# %% [markdown]
# ## Perceptrón
#
# También conocido como neurona de una red neuronal.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regresión lineal simple
#
# $$y=mx+b$$
# $$y=B_0+B_1*X$$
#
# Busca predecir a partir de una formula el valor de un

# %%
from numpy.linalg import lstsq

x= np.array([1.2,2,3.2,2.5,5,6,4,8])
y= np.array([2,3,3.4,3.1,4,4.7,3.8,7])

m, b = lstsq(np.vstack([x, np.ones(len(x))]).T, y, rcond=None)[0]

print("Pendiente (m):", m)
print("Intercepto (b):", b)
# Out:
# Pendiente (m): 0.638631354301508
# Intercepto (b): 1.3284574747227373

# %%
fig, ax = plt.subplots()
plt.scatter(x,y, color = 'mediumblue', alpha=0.6)
ax.set_xlabel('x',fontsize=16)
ax.set_ylabel('y',fontsize=16)
ax.axline((0, b), slope=m, color='red', linewidth=2)
plt.show()

# %% [markdown]
# ### Error
#
# $$MSE = \frac{\sum\limits_{i=1}^n (y_i - \hat{y}_i)^2}{n}$$
#
# $$MAE = \frac{\sum\limits_{i=1}^n |y_i - \hat{y}_i|}{n}$$
#
# $$RMSE = \sqrt{\frac{\sum\limits_{i=1}^n (y_i - \hat{y}_i)^2}{n}}$$
#
# $$Error relativo = \frac{y_i - \hat{y}_i}{y_i}$$
#
# $$Error de pronóstico = y_i - \hat{y}_i$$
#
# ![image.png](attachment:image.png)
